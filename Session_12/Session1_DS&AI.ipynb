# %% [markdown]
# #Print Function

# %%
print("hello python")
# Out:
# hello python

# %%
print("Data Science & Ai")
# Out:
# Data Science & Ai

# %%
print("Data Science","Python")
# Out:
# Data Science Python

# %%
print("sylvia","olaa","mostafa",sep="+")
# Out:
# sylvia+olaa+mostafa

# %% [markdown]
# #Variables

# %% [markdown]
# ![memory-org1.gif](data:image/gif;base64,...)

# %%
name="Sylvia"

# %%
age=24

# %%
address="Masr El gadida"

# %%
print(name,age , address)
# Out:
# Sylvia 24 Masr El gadida

# %% [markdown]
# #Data Types

# %% [markdown]
# ###Numeric
# ##### Int
# ##### Float

# %%
# kjxhhj hjhb
x=2 # int

# %%
y=2.66666 #Float

# %% [markdown]
# ###Bool

# %%
flag=True

# %%
type(flag)
# Out:
# bool

# %%
flag_2=False

# %% [markdown]
# ###String

# %%
name="Sylvixb vh,bjn,b,ja" #string=text

# %%
type(name)
# Out:
# str

# %% [markdown]
# #Sequence

# %% [markdown]
# ####List

# %%
my_list=[1,5,80,90]

# %% [markdown]
# ####Tuple

# %%
tup=(1,80,5,90)

# %% [markdown]
# ####set

# %%
sett={1,80,90,5}

# %% [markdown]
# ####Dictionary

# %%
dic={
    'name':"Mariam",
    'age' : 22,
    'Grade':80
}

# %% [markdown]
# #Convert data types

# %%
mobile_number=1202251511
print(type(mobile_number))
# Out:
# <class 'int'>

# %%
mobile_number=str(mobile_number)

# %%
print(type(mobile_number))
# Out:
# <class 'str'>

# %%
x=20.5
x=bool(x)
print(type(x))
print(x)
# Out:
# <class 'bool'>
# True

# %%
x=0
x=bool(x)#Casting
type(x)#Data Type
# Out:
# bool

# %%
x=200
#Casting bool
y=20.5
#casting int

# %% [markdown]
# #Arithmetic Operation

# %%
# Add
print(5+5)
# Out:
# 10

# %%
# Sub
print(5-5)
# Out:
# 0

# %%
# mul
print(5*5)
# Out:
# 25

# %%
# Floor Divion
print(10//3)
# Out:
# 3

# %%
# power
print(3**2)
# Out:
# 9

# %% [markdown]
# #Input

# %%
password=int(input("Enter your password : "))
# Out:
# Enter your password : 123

# %% [markdown]
# #String

# %%
name="sylvia"

# %%
string="""
vfgyhnjm
ghjklctfvygbhnjim,l.
fgyhjkl;.'
"""

# %%
print(string)
# Out:
# vfgyhnjm
# ghjklctfvygbhnjim,l.
# fgyhjkl;.'

# %%
print(s1)
# Out:
#     jhhfghjhk
#     jhcsguyk
#     jkcsghudh

# %% [markdown]
# #string indexing

# %% [markdown]
# ![string indexing 2.png](data:image/png;base64,...)

# %% [markdown]
# ![String Indexing.webp](data:image/webp;base64,...)

# %%
name="olaa"
name[0]
# Out:
# 'o'

# %%
name[-1]
# Out:
# 'a'

# %% [markdown]
# #Slicing

# %% [markdown]
# ![Slicing-in-Python.webp](data:image/webp;base64,...)

# %%
x="session one"
x[0:4]
# Out:
# 'sess'

# %%
x[:6]
# Out:
# 'sessio'

# %%
x[:]
# Out:
# 'session one'

# %%
x[::2]
# Out:
# 'ssinoe'

# %% [markdown]
# #string operation

# %%
frist_name="mariam "
last_name=" adel"
full_name=frist_name+last_name
print(full_name)
# Out:
# mariam  adel

# %% [markdown]
# ![Concat.png](data:image/png;base64,...)

# %%
first_name="Mariam"*3
print(first_name)
# Out:
# MariamMariamMariam

# %% [markdown]
# #String functions

# %%
x="sylvia"

# %%
x.upper()
# Out:
# 'SYLVIA'

# %%
x.lower()
# Out:
# 'sylvia'

# %%
x="hello-python-C++-Dax-C#"
x.split("-")
# Out:
# ['hello', 'python', 'C++', 'Dax', 'C#']

# %%
number1=10
number2=20
add=number1+number2
sub=number1-number2
mul=number1*number2
div=number1/number2
print("add = ",add)
print("sub = ",sub)
print("mul = ",mul)
print("div = ",div)
# Out:
# add =  30
# sub =  -10
# mul =  200
# div =  0.5

# %% [markdown]
# #Get the Area of the circle

# %%
bi=3.14
r=int(input("Enter the r"))
result=bi*r*r
print(result)
# Out:
# Enter the r2
# 12.56

# %% [markdown]
# #Get the "&" Operator

# %%
x="Data Science & Ai"
x[13]
# Out:
# '&'

# %% [markdown]
# #List

# %%
#create an empty list
empty_list=[]

#create a list with elements
numbers_list=[1,2,3,4,5]

#create list of names
names_list=["Alice","Bob","Charlie"]

#create mix_list
mix_list=[1,"Alice",3.14,True]

# %%
x=[10,20,30,40]
x[2]
# Out:
# 30

# %%
x[-1]
# Out:
# 40

# %%
x[-2]
# Out:
# 30

# %%
x[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-191521982.py in <cell line: 0>()
# ----> 1 x[5]
#
# IndexError: list index out of range

# %% [markdown]
# #List Slicing

# %% [markdown]
# ![Slicing-in-Python.webp](data:image/webp;base64,...)

# %%
x=[10,20,30,40,50,60,70,80,90]
x[2:5]
# Out:
# [30, 40, 50]

# %%
x[:3]
# Out:
# [10, 20, 30]

# %%
x[5:]
# Out:
# [60, 70, 80, 90]

# %%
x=['Sylvia','mariam','bosyy']
x[2][1]
# Out:
# 'o'

# %%
x1=['Sylvia','mariam','bosyy']
x2=['Sylvia_1','mariam_1','bosyy_1']
x3=['Sylvia_2','mariam_2','bosyy_2']

x=[x1,x2,x3]
x
# Out:
# [['Sylvia', 'mariam', 'bosyy'],
#  ['Sylvia_1', 'mariam_1', 'bosyy_1'],
#  ['Sylvia_2', 'mariam_2', 'bosyy_2']]

# %%
x[0][1]
# Out:
# 'mariam'

# %%
x=[1,2,3,4,5,6]
len(x)
# Out:
# 6

# %%
min(x)
# Out:
# 1

# %%
max(x)
# Out:
# 6

# %%
sum(x)
# Out:
# 21

# %%
x=[1,2,3,4,5,6]
x.append(7)
x
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
x=[1,2,3,4,5,6]
x.insert(0,0)
x
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ###remove(value)
# ###pop(index)

# %%
x=[1,2,3,4,5,6]
x.remove(4)
x
# Out:
# [1, 2, 3, 5, 6]

# %%
x=[1,2,3,4,5,6]
x=x.pop(2)
x
# Out:
# 3

# %%
len(x)
# Out:
# 6

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# #Tuple

# %%
x=(1,2,"Sylvia",4,5)
y=("Mariam",20,True)
y[0]
# Out:
# 'Mariam'

# %%
t1=(1,2)
t2=(3,4)
print(t1+t2)
t3=t1+t2
# Out:
# (1, 2, 3, 4)

# %%
x.index("Sylvia")
# Out:
# 2

# %%
x.append(2)
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_274/2024024113.py in <cell line: 0>()
# ----> 1 x.append(2)
#       2 x
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# #Set

# %%
x={1,2,3,4,5,6}
x.add(3)
x.add(5)
x
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# #Dictionary

# %%
dic={'name':'Sylvia',
     'age':24,
}
print(dic['name'])
# Out:
# Sylvia

# %%
dic.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
dic.values()
# Out:
# dict_values(['Sylvia', 24])

# %%
dic.items()
# Out:
# dict_items([('name', 'Sylvia'), ('age', 24)])

# %%
dic={'name':'Sylvia',
     'age':24,
}

dic.update({'Grade':80})
print(dic)
# Out:
# {'name': 'Sylvia', 'age': 24, 'Grade': 80}

# %%
dic['age']
# Out:
# 24
