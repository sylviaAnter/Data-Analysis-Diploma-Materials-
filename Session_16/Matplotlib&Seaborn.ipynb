# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
x=np.random.randint(1,10,5)
y=x**2

# %%
x
# Out:
# array([4, 7, 3, 2, 1])

# %%
y
# Out:
# array([16, 49,  9,  4,  1])

# %% [markdown]
# #Matplotlib

# %% [markdown]
# #Plot

# %%
plt.plot(x,y,'r')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
plt.show()

# %% [markdown]
# #Scatter
# #### rasm bayanii bywd7 el 3alka biin 2 features

# %%
age = [15,25,35,45,55]
salaries = [2000,4000,6000,8000,10000]

plt.scatter(age,salaries,color='r')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Relation between Age & salary')
plt.show()

# %% [markdown]
# #Bar

# %%
x=np.arange(10)
y=np.random.randint(1,10,10)
plt.bar(x,y)
plt.show()

# %% [markdown]
# #Pie

# %%
z=np.random.randint(1,10,4)
plt.pie(z)
plt.show()

# %% [markdown]
# #create multiplots on same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(x,y,'g*-')
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*-')
plt.subplot(2,2,3)
plt.plot(x,y,'b+-')
plt.subplot(2,2,4)
plt.plot(x,y,'y*-')
plt.show()

# %% [markdown]
# #Legends

# %%
plt.plot(x,x**2,label='First Line')
plt.plot(x,y**2,label='Second Line')
plt.legend()
plt.show()

# %% [markdown]
# #Seaborn

# %%
df=pd.read_excel("/content/Employees.xlsx")
df.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1      ahmed     shady    Male 2018-04-04      7     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      5     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      8  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      7       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      6       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Overtime Hours
# 0             183
# 1             198
# 2             192
# ...

# %%
df.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Overtime Hours'],
#       dtype='object')

# %% [markdown]
# #Histogram , Distplot

# %%
sns.displot(df['Annual Salary'])
plt.show()

# %%
sns.histplot(df['Monthly Salary'])
plt.show()

# %% [markdown]
# #Jointplot
# ####Jointplot = Scatter + Histogram + Histogram

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='Monthly Salary',y='Overtime Hours' ,data=df,kind='scatter')
plt.show()

# %%
sns.jointplot(x='Monthly Salary',y='Overtime Hours' ,data=df,kind='hex')
plt.show()

# %% [markdown]
# #Pairplot

# %%
df.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Overtime Hours'],
#       dtype='object')

# %%
# df=df.drop('No',axis=1)
# df=df.drop('Years',axis=1)
df=df.drop('Annual Salary',axis=1)

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df,hue='Gender',palette='plasma')
plt.show()

# %% [markdown]
# #Bar chart in sns

# %%
sns.barplot(x='Gender',y='Monthly Salary',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Job Rate',
#        'Overtime Hours'],
#       dtype='object')

# %%
sns.barplot(x='Center',y='Monthly Salary',data=df)
plt.show()

# %% [markdown]
# #Count plot

# %%
sns.countplot(x='Gender',data=df)
plt.show()

# %% [markdown]
# #Boxplot

# %%
sns.boxplot(x='Center',y='Monthly Salary',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Job Rate',
#        'Overtime Hours'],
#       dtype='object')

# %%
sns.boxplot(x='Country',y='Monthly Salary',data=df,hue='Gender',palette='plasma')
plt.show()

# %% [markdown]
# #Heatmap

# %%
pivot = df.pivot_table(
    index='Years',            # الصفوف
    columns='Country',        # الأعمدة (أو أي فئة)
    values='Monthly Salary',  # القيم
    aggfunc='mean'            # أو sum, max, إلخ
)

# %%
sns.heatmap(pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.show()
