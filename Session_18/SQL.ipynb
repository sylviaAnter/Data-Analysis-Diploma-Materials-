# %% [markdown]
# #What is Database ?

# %% [markdown]
# A database is simply a place where data is stored in an organized way so it can be easily accessed, managed, and updated

# %% [markdown]
# ![iStock-606202164-1024x717.jpg](data:image/jpeg;base64,...)
#
# ![jenis-jenis-database.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #🗄️ DBMS (Database Management System)

# %% [markdown]
# system , software interface between user and DB

# %% [markdown]
# ![5020250312180234.webp](data:image/webp;base64,...)

# %% [markdown]
# #RDBMS (Relational Database Management System)

# %% [markdown]
# ![DBMS-vs-RDBMS-DP.jpg.webp](data:image/webp;base64,...)

# %% [markdown]
# ![RDBMS-Relational-DB-Structure.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #EXamples
# ###1- SQL Server
# ###2- MySql

# %% [markdown]
# ![sql.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #🧾 What is SQL?
#
# SQL stands for Structured Query Language.
#
# It is a language used to communicate with databases.

# %% [markdown]
# ![using-sql-as-keyword-and-join-clause-.png](data:image/png;base64,...)

# %% [markdown]
# #Full Structure of SQL
#
# Structure of SQL (How SQL is organized)

# %% [markdown]
# ![command types in SQL DataBase.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #1-DDL
# ###DDL (Data Definition Language)
# ###DDL is the part of SQL used to create and change the structure of a database.

# %% [markdown]
# ![12.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #What DDL does
#
#
# 1.   Create table
# 2.   Change structure = Alter
# 3.   Delete table = DROP

# %% [markdown]
# ![ddl_commands.png](data:image/png;base64,...)

# %% [markdown]
# #2- DML (Data Manipulation Language)
# ###DML is the part of SQL used to work with the data inside tables.
# ####DML deals with data itself, not the structure.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# #DQL (Data Query Language)
# ####search and read
# ####DQL is only for getting data, not changing it.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# #WHERE statement in SQL
# ####The WHERE clause is used in SQL to filter data — meaning it helps you get only the rows that meet a specific condition.

# %% [markdown]
# ![Data record filtering for terminology management.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-12 144618.png](data:image/png;base64,...)

# %% [markdown]
# #“Family” of SELECT statement

# %% [markdown]
# ![SQL SELECT statement family tree.png](data:image/png;base64,...)
